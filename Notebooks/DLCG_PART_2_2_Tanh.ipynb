# %%
# !unzip "/content/face_images.zip" -d "/content/data"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tensorflow as tf
import cv2
import os

import glob

# %%
img_data = []
for img in os.listdir("/content/data/face_images"):
  img_file = cv2.imread("/content/data/face_images/" + img)
  if(type(img_file) != type(None)):
    img_data.append(img_file)

# %%
len(img_data)
# Out:
# 750

# %%
# https://towardsdatascience.com/complete-image-augmentation-in-opencv-31a6b02694f5
import random

def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img

# HORIZONTAL SHIFT - RANDOM RATIO 0 - 1
def horizontal_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = w*ratio
    if ratio > 0:
        img = img[:, :int(w-to_shift), :]
    if ratio < 0:
        img = img[:, int(-1*to_shift):, :]
    img = fill(img, h, w)
    return img

# VERTICAL SHIFT - RANDOM RATIO 0 - 1
def vertical_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = h*ratio
    if ratio > 0:
        img = img[:int(h-to_shift), :, :]
    if ratio < 0:
        img = img[int(-1*to_shift):, :, :]
    img = fill(img, h, w)
    return img

# BRIGHTNESS - RANDOM LOW, HIGH 
def brightness(img, low, high):
    value = random.uniform(low, high)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv = np.array(hsv, dtype = np.float64)
    hsv[:,:,1] = hsv[:,:,1]*value
    hsv[:,:,1][hsv[:,:,1]>255]  = 255
    hsv[:,:,2] = hsv[:,:,2]*value 
    hsv[:,:,2][hsv[:,:,2]>255]  = 255
    hsv = np.array(hsv, dtype = np.uint8)
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return img

# ZOOM - RANDOM VALUE 0 - 1
def zoom(img, value):
    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, h, w)
    return img

# HORIZONTAL FLIP - RANDOM BOOLEAN
def horizontal_flip(img, flag):
    if flag:
        return cv2.flip(img, 1)
    else:
        return img

# VERTICAL FLIP - RANDOM BOOLEAN
def vertical_flip(img, flag):
    if flag:
        return cv2.flip(img, 0)
    else:
        return img

# ROTATION - RANDOM ANGLE
def rotation(img, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = img.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    img = cv2.warpAffine(img, M, (w, h))
    return img
  
# SCALE - RANDOM VALUE 0.6 - 1
def scale(img, value):
  return np.array((value * img), dtype=np.uint8)

# %%
import random
train_indices = []
for i in range(675):
  x = random.randint(0, 749)
  while(x in train_indices):
    x = random.randint(0, 749)
  train_indices.append(x)
print(len(train_indices))
train_indices = list(set(train_indices))
print(len(train_indices))
# Out:
# 675
# 675

# %%
train_data = []
test_data = []

for i in range(750):
  if(i in train_indices):
    train_data.append(img_data[i])
  else:
    test_data.append(img_data[i])

train_data = np.array(train_data)
test_data = np.array(test_data)

train_data.shape, test_data.shape, test_data.dtype
# Out:
# ((675, 128, 128, 3), (75, 128, 128, 3), dtype('uint8'))

# %%
augmented_train_data = []
for i in train_data:
  augmented_train_data.append(i)
  for j in range(3):
    augmented_train_data.append(horizontal_shift(i, random.uniform(0, 1)))
    augmented_train_data.append(vertical_shift(i, random.uniform(0, 1)))
    augmented_train_data.append(zoom(i, random.uniform(0, 1)))
    augmented_train_data.append(scale(i, random.uniform(0.6, 1)))

# %%
X_train_data = []
y_train_data = []
for img in augmented_train_data:
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  X_train_data.append([L])
  y_train_data.append([a,b])

# %%
X_test_data = []
y_test_data = []
for img in test_data:
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  X_test_data.append([L])
  y_test_data.append([a,b])

# %%
X_train = np.array(X_train_data, dtype = np.float32)
X_test = np.array(X_test_data, dtype = np.float32)
y_train = np.array(y_train_data, dtype = np.float32)
y_test = np.array(y_test_data, dtype = np.float32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8775, 1, 128, 128),
#  (75, 1, 128, 128),
#  (8775, 2, 128, 128),
#  (75, 2, 128, 128))

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
y_train = y_train - 144
y_test = y_test - 144

# %%
y_train = y_train / 51
y_test = y_test / 51

# %%
y_train.min(), y_train.max(), y_test.min(), y_test.max()
# Out:
# (-1.0, 1.0, -0.92156863, 0.9607843)

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Conv2D, Conv2DTranspose, BatchNormalization
model = Sequential()
model.add(Input(shape = (X_train[0].shape)))
model.add(Conv2D(128, 2, activation = "relu",strides = 1,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(256, 1, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(128, 2, activation = "relu",strides =  (2, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(64, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(32, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(16, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(8, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(8, 2, activation = "relu",strides = (2, 1),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(16, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(32, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(64, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(128, 2, activation = "tanh",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(256, 2, activation = "tanh",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(128, 2, activation = "tanh",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_63 (Conv2D)          (None, 1, 128, 128)       65664
#
#  batch_normalization_126 (Ba  (None, 1, 128, 128)      512
#  tchNormalization)
#
#  conv2d_transpose_63 (Conv2D  (None, 1, 256, 256)      33024
#  Transpose)
#
#  batch_normalization_127 (Ba  (None, 1, 256, 256)      1024
#  tchNormalization)
#
#  conv2d_64 (Conv2D)          (None, 1, 128, 128)       131200
#
#  batch_normalization_128 (Ba  (None, 1, 128, 128)      512
#  tchNormalization)
#
#  conv2d_65 (Conv2D)          (None, 1, 64, 64)         32832
#
#  batch_normalization_129 (Ba  (None, 1, 64, 64)        256
#  tchNormalization)
#
#  conv2d_66 (Conv2D)          (None, 1, 32, 32)         8224
#
#  batch_normalization_130 (Ba  (None, 1, 32, 32)        128
#  tchNormalization)
#
#  conv2d_67 (Conv2D)          (None, 1, 16, 16)         2064
#
#  batch_normalization_131 (Ba  (None, 1, 16, 16)        64
#  tchNormalization)
#
#  conv2d_68 (Conv2D)          (None, 1, 8, 8)           520
#
#  batch_normalization_132 (Ba  (None, 1, 8, 8)          32
#  tchNormalization)
#
#  conv2d_transpose_64 (Conv2D  (None, 2, 8, 8)          264
#  Transpose)
#
#  batch_normalization_133 (Ba  (None, 2, 8, 8)          32
#  tchNormalization)
#
#  conv2d_transpose_65 (Conv2D  (None, 2, 16, 16)        528
#  Transpose)
#
#  batch_normalization_134 (Ba  (None, 2, 16, 16)        64
#  tchNormalization)
#
#  conv2d_transpose_66 (Conv2D  (None, 2, 32, 32)        2080
#  Transpose)
#
#  batch_normalization_135 (Ba  (None, 2, 32, 32)        128
#  tchNormalization)
#
#  conv2d_transpose_67 (Conv2D  (None, 2, 64, 64)        8256
#  Transpose)
#
#  batch_normalization_136 (Ba  (None, 2, 64, 64)        256
#  tchNormalization)
#
#  conv2d_transpose_68 (Conv2D  (None, 2, 128, 128)      32896
#  Transpose)
#
#  batch_normalization_137 (Ba  (None, 2, 128, 128)      512
#  tchNormalization)
#
#  conv2d_transpose_69 (Conv2D  (None, 2, 256, 256)      131328
#  Transpose)
#
#  batch_normalization_138 (Ba  (None, 2, 256, 256)      1024
#  tchNormalization)
#
#  conv2d_69 (Conv2D)          (None, 2, 128, 128)       131200
#
#  batch_normalization_139 (Ba  (None, 2, 128, 128)      512
#  tchNormalization)
#
# =================================================================
# Total params: 585,136
# Trainable params: 582,608
# Non-trainable params: 2,528
# _________________________________________________________________

# %%
loss = tf.keras.losses.MeanSquaredError(name='mean_squared_error')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss=loss)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lrr = ReduceLROnPlateau(monitor='val_loss', 
                        patience=7, 
                        verbose=1, 
                        factor=0.4, 
                        min_lr=0.0001)

# %%
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=50, 
                    batch_size=25,
                    steps_per_epoch=X_train.shape[0]//25,
                    validation_steps=X_test.shape[0]//25,
                    callbacks=[lrr],
                    shuffle=True)
# Out:
# Epoch 1/50
# 351/351 [==============================] - 6s 16ms/step - loss: 0.2018 - val_loss: 0.0494 - lr: 0.0010
# Epoch 2/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0137 - val_loss: 0.0136 - lr: 0.0010
# Epoch 3/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0129 - val_loss: 0.0124 - lr: 0.0010
# Epoch 4/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0121 - val_loss: 0.0120 - lr: 0.0010
# Epoch 5/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0116 - val_loss: 0.0114 - lr: 0.0010
# Epoch 6/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0113 - val_loss: 0.0118 - lr: 0.0010
# Epoch 7/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0110 - val_loss: 0.0129 - lr: 0.0010
# Epoch 8/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0109 - val_loss: 0.0115 - lr: 0.0010
# Epoch 9/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0107 - val_loss: 0.0111 - lr: 0.0010
# Epoch 10/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0105 - val_loss: 0.0123 - lr: 0.0010
# Epoch 11/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0104 - val_loss: 0.0120 - lr: 0.0010
# Epoch 12/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0101 - val_loss: 0.0125 - lr: 0.0010
# Epoch 13/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0099 - val_loss: 0.0142 - lr: 0.0010
# Epoch 14/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0096 - val_loss: 0.0116 - lr: 0.0010
# Epoch 15/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0094 - val_loss: 0.0116 - lr: 0.0010
# Epoch 16/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0091 - val_loss: 0.0105 - lr: 0.0010
# Epoch 17/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0089 - val_loss: 0.0100 - lr: 0.0010
# Epoch 18/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0088 - val_loss: 0.0113 - lr: 0.0010
# Epoch 19/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0086 - val_loss: 0.0097 - lr: 0.0010
# Epoch 20/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0085 - val_loss: 0.0116 - lr: 0.0010
# Epoch 21/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0084 - val_loss: 0.0113 - lr: 0.0010
# Epoch 22/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0083 - val_loss: 0.0116 - lr: 0.0010
# Epoch 23/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0081 - val_loss: 0.0093 - lr: 0.0010
# Epoch 24/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0080 - val_loss: 0.0120 - lr: 0.0010
# Epoch 25/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0079 - val_loss: 0.0089 - lr: 0.0010
# Epoch 26/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0079 - val_loss: 0.0093 - lr: 0.0010
# Epoch 27/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0077 - val_loss: 0.0089 - lr: 0.0010
# Epoch 28/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0077 - val_loss: 0.0096 - lr: 0.0010
# Epoch 29/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0076 - val_loss: 0.0101 - lr: 0.0010
# Epoch 30/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0074 - val_loss: 0.0100 - lr: 0.0010
# Epoch 31/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0075 - val_loss: 0.0097 - lr: 0.0010
# Epoch 32/50
# 349/351 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0073 - val_loss: 0.0100 - lr: 0.0010
# Epoch 33/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0068 - val_loss: 0.0089 - lr: 4.0000e-04
# Epoch 34/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0067 - val_loss: 0.0086 - lr: 4.0000e-04
# Epoch 35/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0067 - val_loss: 0.0092 - lr: 4.0000e-04
# Epoch 36/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0065 - val_loss: 0.0091 - lr: 4.0000e-04
# Epoch 37/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0065 - val_loss: 0.0086 - lr: 4.0000e-04
# Epoch 38/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0065 - val_loss: 0.0092 - lr: 4.0000e-04
# Epoch 39/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0065 - val_loss: 0.0087 - lr: 4.0000e-04
# Epoch 40/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0065 - val_loss: 0.0088 - lr: 4.0000e-04
# Epoch 41/50
# 349/351 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0064 - val_loss: 0.0092 - lr: 4.0000e-04
# Epoch 42/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0061 - val_loss: 0.0089 - lr: 1.6000e-04
# Epoch 43/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0061 - val_loss: 0.0085 - lr: 1.6000e-04
# Epoch 44/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0061 - val_loss: 0.0089 - lr: 1.6000e-04
# Epoch 45/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0084 - lr: 1.6000e-04
# Epoch 46/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0086 - lr: 1.6000e-04
# Epoch 47/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0059 - val_loss: 0.0084 - lr: 1.6000e-04
# Epoch 48/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0088 - lr: 1.6000e-04
# Epoch 49/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0085 - lr: 1.6000e-04
# Epoch 50/50
# 351/351 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0086 - lr: 1.6000e-04

# %%
# PLOTTING THE ACCURACY AND VALIDATION ACCURACY VS EPOCHS
from matplotlib import pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Mean Squared Error')
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("/content//ColorizerModelFinalTanh.h5")

# %%
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0086
# 0.008574645034968853

# %%
def predict(imgpath, flag):
  img = cv2.imread(imgpath)
  img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
  print(img.shape)
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  L = L.reshape(1 , 1, 128, 128)
  L = L/255
  pred = model.predict(L)
  a = pred[0][0]
  b = pred[0][1]
  L = L.reshape(128,128)
  L = np.array(L * 255, dtype = np.uint8)
  a = np.array(a * 51, dtype = np.float32)
  b = np.array(b * 51, dtype = np.float32)
   
  a = a + 144
  b = b + 144

  a = np.array(a, dtype = np.uint8)
  b = np.array(b, dtype = np.uint8)

  imgLAB = cv2.merge([L, a, b])
  image = cv2.cvtColor(imgLAB, cv2.COLOR_LAB2RGB)
  fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(5,8))

  ax1.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  ax1.set_title("Original Image")
  ax2.imshow(image)
  ax2.set_title("Colorized")
  ax3.imshow(a)
  ax3.set_title("a")
  ax4.imshow(b)
  ax4.set_title("b")
  # cv2.imwrite("/content/img.jpg", cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
  # if(not flag):
  #   image = predict("/content/img.jpg", True)
  return image

# %%
image = predict("/content/2.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 302ms/step

# %%
image = predict("/content/3.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 18ms/step

# %%
image = predict("/content/4.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 17ms/step

# %%
image = predict("/content/5.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 18ms/step

# %%
image = predict("/content/6.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 17ms/step

# %%
image = predict("/content/7.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 18ms/step

# %%
image = predict("/content/8.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 16ms/step

# %%
image = predict("/content/data/face_images/image00080.jpg", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 17ms/step
