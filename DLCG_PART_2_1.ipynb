# %%
# !unzip "/content/drive/MyDrive/DLCG_PART_2/face_images.zip" -d "/content/data"
# Out:
# Archive:  /content/drive/MyDrive/DLCG_PART_2/face_images.zip
#    creating: /content/data/face_images/
#   inflating: /content/data/face_images/image00729.jpg
#   inflating: /content/data/face_images/image00013.jpg
#   inflating: /content/data/face_images/image00609.jpg
#   inflating: /content/data/face_images/image00592.jpg
#   inflating: /content/data/face_images/image00097.jpg
#   inflating: /content/data/face_images/image00591.jpg
#   inflating: /content/data/face_images/image00394.jpg
#   inflating: /content/data/face_images/rename.py
#   inflating: /content/data/face_images/image00281.jpg
#   inflating: /content/data/face_images/image00540.jpg
#   inflating: /content/data/face_images/image00675.jpg
#   inflating: /content/data/face_images/image00511.jpg
#   inflating: /content/data/face_images/image00361.jpg
#   inflating: /content/data/face_images/image00154.jpg
#   inflating: /content/data/face_images/image00472.jpg
#   inflating: /content/data/face_images/image00310.jpg
#   inflating: /content/data/face_images/image00273.jpg
#   inflating: /content/data/face_images/image00335.jpg
#   inflating: /content/data/face_images/image00286.jpg
#   inflating: /content/data/face_images/image00747.jpg
#   inflating: /content/data/face_images/image00206.jpg
#   inflating: /content/data/face_images/image00004.jpg
#   inflating: /content/data/face_images/image00114.jpg
#   inflating: /content/data/face_images/image00390.jpg
#   inflating: /content/data/face_images/image00525.jpg
#   inflating: /content/data/face_images/image00345.jpg
#   inflating: /content/data/face_images/image00151.jpg
#   inflating: /content/data/face_images/image00029.jpg
#   inflating: /content/data/face_images/image00352.jpg
#   inflating: /content/data/face_images/image00451.jpg
#   inflating: /content/data/face_images/image00519.jpg
#   inflating: /content/data/face_images/image00645.jpg
#   inflating: /content/data/face_images/image00682.jpg
#   inflating: /content/data/face_images/image00309.jpg
#   inflating: /content/data/face_images/image00478.jpg
#   inflating: /content/data/face_images/image00010.jpg
#   inflating: /content/data/face_images/image00670.jpg
#   inflating: /content/data/face_images/image00014.jpg
#   inflating: /content/data/face_images/image00141.jpg
#   inflating: /content/data/face_images/image00416.jpg
#   inflating: /content/data/face_images/image00419.jpg
#   inflating: /content/data/face_images/image00210.jpg
#   inflating: /content/data/face_images/image00377.jpg
#   inflating: /content/data/face_images/image00236.jpg
#   inflating: /content/data/face_images/image00188.jpg
#   inflating: /content/data/face_images/image00623.jpg
#   inflating: /content/data/face_images/image00265.jpg
#   inflating: /content/data/face_images/image00607.jpg
#   inflating: /content/data/face_images/image00652.jpg
#   inflating: /content/data/face_images/image00344.jpg
#   inflating: /content/data/face_images/image00366.jpg
#   inflating: /content/data/face_images/image00099.jpg
#   inflating: /content/data/face_images/image00391.jpg
#   inflating: /content/data/face_images/image00423.jpg
#   inflating: /content/data/face_images/image00727.jpg
#   inflating: /content/data/face_images/image00552.jpg
#   inflating: /content/data/face_images/image00664.jpg
#   inflating: /content/data/face_images/image00622.jpg
#   inflating: /content/data/face_images/image00007.jpg
#   inflating: /content/data/face_images/image00226.jpg
#   inflating: /content/data/face_images/image00737.jpg
#   inflating: /content/data/face_images/image00734.jpg
#   inflating: /content/data/face_images/image00556.jpg
#   inflating: /content/data/face_images/image00544.jpg
#   inflating: /content/data/face_images/image00684.jpg
#   inflating: /content/data/face_images/image00006.jpg
#   inflating: /content/data/face_images/image00672.jpg
#   inflating: /content/data/face_images/image00196.jpg
#   inflating: /content/data/face_images/image00743.jpg
#   inflating: /content/data/face_images/image00620.jpg
#   inflating: /content/data/face_images/image00088.jpg
#   inflating: /content/data/face_images/image00367.jpg
#   inflating: /content/data/face_images/image00705.jpg
#   inflating: /content/data/face_images/image00709.jpg
#   inflating: /content/data/face_images/image00409.jpg
#   inflating: /content/data/face_images/image00197.jpg
#   inflating: /content/data/face_images/image00732.jpg
#   inflating: /content/data/face_images/image00322.jpg
#   inflating: /content/data/face_images/image00167.jpg
#   inflating: /content/data/face_images/image00541.jpg
#   inflating: /content/data/face_images/image00723.jpg
#   inflating: /content/data/face_images/image00142.jpg
#   inflating: /content/data/face_images/image00564.jpg
#   inflating: /content/data/face_images/image00129.jpg
#   inflating: /content/data/face_images/image00615.jpg
#   inflating: /content/data/face_images/image00161.jpg
#   inflating: /content/data/face_images/image00321.jpg
#   inflating: /content/data/face_images/image00122.jpg
#   inflating: /content/data/face_images/image00026.jpg
#   inflating: /content/data/face_images/image00598.jpg
#   inflating: /content/data/face_images/image00407.jpg
#   inflating: /content/data/face_images/image00638.jpg
#   inflating: /content/data/face_images/image00539.jpg
#   inflating: /content/data/face_images/image00112.jpg
#   inflating: /content/data/face_images/image00153.jpg
#   inflating: /content/data/face_images/image00090.jpg
#   inflating: /content/data/face_images/image00291.jpg
#   inflating: /content/data/face_images/image00502.jpg
#   inflating: /content/data/face_images/image00317.jpg
#   inflating: /content/data/face_images/image00571.jpg
#   inflating: /content/data/face_images/image00650.jpg
#   inflating: /content/data/face_images/image00313.jpg
#   inflating: /content/data/face_images/image00433.jpg
#   inflating: /content/data/face_images/image00287.jpg
#   inflating: /content/data/face_images/image00627.jpg
#   inflating: /content/data/face_images/image00289.jpg
#   inflating: /content/data/face_images/image00506.jpg
#   inflating: /content/data/face_images/image00347.jpg
#   inflating: /content/data/face_images/image00272.jpg
#   inflating: /content/data/face_images/image00459.jpg
#   inflating: /content/data/face_images/image00401.jpg
#   inflating: /content/data/face_images/image00056.jpg
#   inflating: /content/data/face_images/image00634.jpg
#   inflating: /content/data/face_images/image00720.jpg
#   inflating: /content/data/face_images/image00686.jpg
#   inflating: /content/data/face_images/image00585.jpg
#   inflating: /content/data/face_images/image00531.jpg
#   inflating: /content/data/face_images/image00611.jpg
#   inflating: /content/data/face_images/image00508.jpg
#   inflating: /content/data/face_images/image00604.jpg
#   inflating: /content/data/face_images/image00694.jpg
#   inflating: /content/data/face_images/image00162.jpg
#   inflating: /content/data/face_images/image00333.jpg
#   inflating: /content/data/face_images/image00378.jpg
#   inflating: /content/data/face_images/image00185.jpg
#   inflating: /content/data/face_images/image00726.jpg
#   inflating: /content/data/face_images/image00716.jpg
#   inflating: /content/data/face_images/image00187.jpg
#   inflating: /content/data/face_images/image00424.jpg
#   inflating: /content/data/face_images/image00001.jpg
#   inflating: /content/data/face_images/image00388.jpg
#   inflating: /content/data/face_images/image00594.jpg
#   inflating: /content/data/face_images/image00588.jpg
#   inflating: /content/data/face_images/image00182.jpg
#   inflating: /content/data/face_images/image00748.jpg
#   inflating: /content/data/face_images/image00624.jpg
#   inflating: /content/data/face_images/image00524.jpg
#   inflating: /content/data/face_images/image00551.jpg
#   inflating: /content/data/face_images/image00393.jpg
#   inflating: /content/data/face_images/image00691.jpg
#   inflating: /content/data/face_images/image00415.jpg
#   inflating: /content/data/face_images/image00324.jpg
#   inflating: /content/data/face_images/image00665.jpg
#   inflating: /content/data/face_images/image00303.jpg
#   inflating: /content/data/face_images/image00134.jpg
#   inflating: /content/data/face_images/image00307.jpg
#   inflating: /content/data/face_images/image00661.jpg
#   inflating: /content/data/face_images/image00269.jpg
#   inflating: /content/data/face_images/image00334.jpg
#   inflating: /content/data/face_images/image00488.jpg
#   inflating: /content/data/face_images/image00009.jpg
#   inflating: /content/data/face_images/image00547.jpg
#   inflating: /content/data/face_images/image00338.jpg
#   inflating: /content/data/face_images/image00438.jpg
#   inflating: /content/data/face_images/image00730.jpg
#   inflating: /content/data/face_images/image00576.jpg
#   inflating: /content/data/face_images/image00745.jpg
#   inflating: /content/data/face_images/image00135.jpg
#   inflating: /content/data/face_images/image00537.jpg
#   inflating: /content/data/face_images/image00587.jpg
#   inflating: /content/data/face_images/image00051.jpg
#   inflating: /content/data/face_images/image00318.jpg
#   inflating: /content/data/face_images/image00744.jpg
#   inflating: /content/data/face_images/image00288.jpg
#   inflating: /content/data/face_images/image00728.jpg
#   inflating: /content/data/face_images/image00084.jpg
#   inflating: /content/data/face_images/image00292.jpg
#   inflating: /content/data/face_images/image00489.jpg
#   inflating: /content/data/face_images/image00191.jpg
#   inflating: /content/data/face_images/image00118.jpg
#   inflating: /content/data/face_images/image00476.jpg
#   inflating: /content/data/face_images/image00048.jpg
#   inflating: /content/data/face_images/image00708.jpg
#   inflating: /content/data/face_images/image00667.jpg
#   inflating: /content/data/face_images/image00066.jpg
#   inflating: /content/data/face_images/image00373.jpg
#   inflating: /content/data/face_images/image00302.jpg
#   inflating: /content/data/face_images/image00179.jpg
#   inflating: /content/data/face_images/image00081.jpg
#   inflating: /content/data/face_images/image00493.jpg
#   inflating: /content/data/face_images/image00105.jpg
#   inflating: /content/data/face_images/image00068.jpg
#   inflating: /content/data/face_images/image00371.jpg
#   inflating: /content/data/face_images/image00690.jpg
#   inflating: /content/data/face_images/image00653.jpg
#   inflating: /content/data/face_images/image00305.jpg
#   inflating: /content/data/face_images/image00038.jpg
#   inflating: /content/data/face_images/image00669.jpg
#   inflating: /content/data/face_images/image00566.jpg
#   inflating: /content/data/face_images/image00015.jpg
#   inflating: /content/data/face_images/image00255.jpg
#   inflating: /content/data/face_images/image00225.jpg
#   inflating: /content/data/face_images/image00049.jpg
#   inflating: /content/data/face_images/image00741.jpg
#   inflating: /content/data/face_images/image00351.jpg
#   inflating: /content/data/face_images/image00175.jpg
#   inflating: /content/data/face_images/image00722.jpg
#   inflating: /content/data/face_images/image00164.jpg
#   inflating: /content/data/face_images/image00252.jpg
#   inflating: /content/data/face_images/image00033.jpg
#   inflating: /content/data/face_images/image00453.jpg
#   inflating: /content/data/face_images/image00279.jpg
#   inflating: /content/data/face_images/image00562.jpg
#   inflating: /content/data/face_images/image00597.jpg
#   inflating: /content/data/face_images/image00703.jpg
#   inflating: /content/data/face_images/image00485.jpg
#   inflating: /content/data/face_images/image00323.jpg
#   inflating: /content/data/face_images/image00290.jpg
#   inflating: /content/data/face_images/image00714.jpg
#   inflating: /content/data/face_images/image00160.jpg
#   inflating: /content/data/face_images/image00530.jpg
#   inflating: /content/data/face_images/image00176.jpg
#   inflating: /content/data/face_images/image00498.jpg
#   inflating: /content/data/face_images/image00184.jpg
#   inflating: /content/data/face_images/image00145.jpg
#   inflating: /content/data/face_images/image00557.jpg
#   inflating: /content/data/face_images/image00177.jpg
#   inflating: /content/data/face_images/image00573.jpg
#   inflating: /content/data/face_images/image00491.jpg
#   inflating: /content/data/face_images/image00156.jpg
#   inflating: /content/data/face_images/image00083.jpg
#   inflating: /content/data/face_images/image00089.jpg
#   inflating: /content/data/face_images/image00382.jpg
#   inflating: /content/data/face_images/image00538.jpg
#   inflating: /content/data/face_images/image00484.jpg
#   inflating: /content/data/face_images/image00568.jpg
#   inflating: /content/data/face_images/image00331.jpg
#   inflating: /content/data/face_images/image00481.jpg
#   inflating: /content/data/face_images/image00470.jpg
#   inflating: /content/data/face_images/image00232.jpg
#   inflating: /content/data/face_images/image00168.jpg
#   inflating: /content/data/face_images/image00000.jpg
#   inflating: /content/data/face_images/image00471.jpg
#   inflating: /content/data/face_images/image00104.jpg
#   inflating: /content/data/face_images/image00235.jpg
#   inflating: /content/data/face_images/image00440.jpg
#   inflating: /content/data/face_images/image00707.jpg
#   inflating: /content/data/face_images/image00412.jpg
#   inflating: /content/data/face_images/image00178.jpg
#   inflating: /content/data/face_images/image00256.jpg
#   inflating: /content/data/face_images/image00233.jpg
#   inflating: /content/data/face_images/image00348.jpg
#   inflating: /content/data/face_images/image00610.jpg
#   inflating: /content/data/face_images/image00448.jpg
#   inflating: /content/data/face_images/image00002.jpg
#   inflating: /content/data/face_images/image00021.jpg
#   inflating: /content/data/face_images/image00298.jpg
#   inflating: /content/data/face_images/image00190.jpg
#   inflating: /content/data/face_images/image00534.jpg
#   inflating: /content/data/face_images/image00427.jpg
#   inflating: /content/data/face_images/image00736.jpg
#   inflating: /content/data/face_images/image00532.jpg
#   inflating: /content/data/face_images/image00680.jpg
#   inflating: /content/data/face_images/image00633.jpg
#   inflating: /content/data/face_images/image00739.jpg
#   inflating: /content/data/face_images/image00360.jpg
#   inflating: /content/data/face_images/image00096.jpg
#   inflating: /content/data/face_images/image00039.jpg
#   inflating: /content/data/face_images/image00692.jpg
#   inflating: /content/data/face_images/image00454.jpg
#   inflating: /content/data/face_images/image00387.jpg
#   inflating: /content/data/face_images/image00666.jpg
#   inflating: /content/data/face_images/image00533.jpg
#   inflating: /content/data/face_images/image00062.jpg
#   inflating: /content/data/face_images/image00688.jpg
#   inflating: /content/data/face_images/image00094.jpg
#   inflating: /content/data/face_images/image00140.jpg
#   inflating: /content/data/face_images/image00520.jpg
#   inflating: /content/data/face_images/image00359.jpg
#   inflating: /content/data/face_images/image00523.jpg
#   inflating: /content/data/face_images/image00249.jpg
#   inflating: /content/data/face_images/image00207.jpg
#   inflating: /content/data/face_images/image00037.jpg
#   inflating: /content/data/face_images/image00462.jpg
#   inflating: /content/data/face_images/image00050.jpg
#   inflating: /content/data/face_images/image00241.jpg
#   inflating: /content/data/face_images/image00267.jpg
#   inflating: /content/data/face_images/image00209.jpg
#   inflating: /content/data/face_images/image00658.jpg
#   inflating: /content/data/face_images/image00719.jpg
#   inflating: /content/data/face_images/image00093.jpg
#   inflating: /content/data/face_images/image00639.jpg
#   inflating: /content/data/face_images/image00086.jpg
#   inflating: /content/data/face_images/image00619.jpg
#   inflating: /content/data/face_images/image00204.jpg
#   inflating: /content/data/face_images/image00593.jpg
#   inflating: /content/data/face_images/image00463.jpg
#   inflating: /content/data/face_images/image00697.jpg
#   inflating: /content/data/face_images/image00702.jpg
#   inflating: /content/data/face_images/image00024.jpg
#   inflating: /content/data/face_images/image00660.jpg
#   inflating: /content/data/face_images/image00231.jpg
#   inflating: /content/data/face_images/image00243.jpg
#   inflating: /content/data/face_images/image00293.jpg
#   inflating: /content/data/face_images/image00422.jpg
#   inflating: /content/data/face_images/image00047.jpg
#   inflating: /content/data/face_images/image00283.jpg
#   inflating: /content/data/face_images/image00008.jpg
#   inflating: /content/data/face_images/image00019.jpg
#   inflating: /content/data/face_images/image00677.jpg
#   inflating: /content/data/face_images/image00107.jpg
#   inflating: /content/data/face_images/image00473.jpg
#   inflating: /content/data/face_images/image00545.jpg
#   inflating: /content/data/face_images/image00074.jpg
#   inflating: /content/data/face_images/image00503.jpg
#   inflating: /content/data/face_images/image00100.jpg
#   inflating: /content/data/face_images/image00475.jpg
#   inflating: /content/data/face_images/image00101.jpg
#   inflating: /content/data/face_images/image00080.jpg
#   inflating: /content/data/face_images/image00644.jpg
#   inflating: /content/data/face_images/image00618.jpg
#   inflating: /content/data/face_images/image00466.jpg
#   inflating: /content/data/face_images/image00282.jpg
#   inflating: /content/data/face_images/image00250.jpg
#   inflating: /content/data/face_images/image00220.jpg
#   inflating: /content/data/face_images/image00496.jpg
#   inflating: /content/data/face_images/image00296.jpg
#   inflating: /content/data/face_images/image00149.jpg
#   inflating: /content/data/face_images/image00676.jpg
#   inflating: /content/data/face_images/image00698.jpg
#   inflating: /content/data/face_images/image00300.jpg
#   inflating: /content/data/face_images/image00092.jpg
#   inflating: /content/data/face_images/image00437.jpg
#   inflating: /content/data/face_images/image00332.jpg
#   inflating: /content/data/face_images/image00198.jpg
#   inflating: /content/data/face_images/image00700.jpg
#   inflating: /content/data/face_images/image00635.jpg
#   inflating: /content/data/face_images/image00312.jpg
#   inflating: /content/data/face_images/image00202.jpg
#   inflating: /content/data/face_images/image00582.jpg
#   inflating: /content/data/face_images/image00507.jpg
#   inflating: /content/data/face_images/image00028.jpg
#   inflating: /content/data/face_images/image00350.jpg
#   inflating: /content/data/face_images/image00253.jpg
#   inflating: /content/data/face_images/image00450.jpg
#   inflating: /content/data/face_images/image00528.jpg
#   inflating: /content/data/face_images/image00043.jpg
#   inflating: /content/data/face_images/image00304.jpg
#   inflating: /content/data/face_images/image00630.jpg
#   inflating: /content/data/face_images/image00023.jpg
#   inflating: /content/data/face_images/image00461.jpg
#   inflating: /content/data/face_images/image00218.jpg
#   inflating: /content/data/face_images/image00699.jpg
#   inflating: /content/data/face_images/image00147.jpg
#   inflating: /content/data/face_images/image00186.jpg
#   inflating: /content/data/face_images/image00657.jpg
#   inflating: /content/data/face_images/image00131.jpg
#   inflating: /content/data/face_images/image00595.jpg
#   inflating: /content/data/face_images/image00061.jpg
#   inflating: /content/data/face_images/image00224.jpg
#   inflating: /content/data/face_images/image00663.jpg
#   inflating: /content/data/face_images/image00510.jpg
#   inflating: /content/data/face_images/image00075.jpg
#   inflating: /content/data/face_images/image00380.jpg
#   inflating: /content/data/face_images/image00158.jpg
#   inflating: /content/data/face_images/image00108.jpg
#   inflating: /content/data/face_images/image00542.jpg
#   inflating: /content/data/face_images/image00579.jpg
#   inflating: /content/data/face_images/image00106.jpg
#   inflating: /content/data/face_images/image00584.jpg
#   inflating: /content/data/face_images/image00119.jpg
#   inflating: /content/data/face_images/image00230.jpg
#   inflating: /content/data/face_images/image00499.jpg
#   inflating: /content/data/face_images/image00384.jpg
#   inflating: /content/data/face_images/image00268.jpg
#   inflating: /content/data/face_images/image00109.jpg
#   inflating: /content/data/face_images/image00417.jpg
#   inflating: /content/data/face_images/image00527.jpg
#   inflating: /content/data/face_images/image00251.jpg
#   inflating: /content/data/face_images/image00477.jpg
#   inflating: /content/data/face_images/image00095.jpg
#   inflating: /content/data/face_images/image00701.jpg
#   inflating: /content/data/face_images/image00328.jpg
#   inflating: /content/data/face_images/image00071.jpg
#   inflating: /content/data/face_images/image00455.jpg
#   inflating: /content/data/face_images/image00070.jpg
#   inflating: /content/data/face_images/image00628.jpg
#   inflating: /content/data/face_images/image00612.jpg
#   inflating: /content/data/face_images/image00098.jpg
#   inflating: /content/data/face_images/image00325.jpg
#   inflating: /content/data/face_images/image00563.jpg
#   inflating: /content/data/face_images/image00386.jpg
#   inflating: /content/data/face_images/image00586.jpg
#   inflating: /content/data/face_images/image00276.jpg
#   inflating: /content/data/face_images/image00117.jpg
#   inflating: /content/data/face_images/image00616.jpg
#   inflating: /content/data/face_images/image00005.jpg
#   inflating: /content/data/face_images/image00673.jpg
#   inflating: /content/data/face_images/image00565.jpg
#   inflating: /content/data/face_images/image00036.jpg
#   inflating: /content/data/face_images/image00052.jpg
#   inflating: /content/data/face_images/image00704.jpg
#   inflating: /content/data/face_images/image00358.jpg
#   inflating: /content/data/face_images/image00180.jpg
#   inflating: /content/data/face_images/image00431.jpg
#   inflating: /content/data/face_images/image00396.jpg
#   inflating: /content/data/face_images/image00072.jpg
#   inflating: /content/data/face_images/image00648.jpg
#   inflating: /content/data/face_images/image00121.jpg
#   inflating: /content/data/face_images/image00521.jpg
#   inflating: /content/data/face_images/image00749.jpg
#   inflating: /content/data/face_images/image00643.jpg
#   inflating: /content/data/face_images/image00057.jpg
#   inflating: /content/data/face_images/image00603.jpg
#   inflating: /content/data/face_images/image00132.jpg
#   inflating: /content/data/face_images/image00284.jpg
#   inflating: /content/data/face_images/image00554.jpg
#   inflating: /content/data/face_images/image00441.jpg
#   inflating: /content/data/face_images/image00678.jpg
#   inflating: /content/data/face_images/image00203.jpg
#   inflating: /content/data/face_images/image00522.jpg
#   inflating: /content/data/face_images/image00479.jpg
#   inflating: /content/data/face_images/image00042.jpg
#   inflating: /content/data/face_images/image00166.jpg
#   inflating: /content/data/face_images/image00329.jpg
#   inflating: /content/data/face_images/image00599.jpg
#   inflating: /content/data/face_images/image00518.jpg
#   inflating: /content/data/face_images/image00174.jpg
#   inflating: /content/data/face_images/image00375.jpg
#   inflating: /content/data/face_images/image00219.jpg
#   inflating: /content/data/face_images/image00102.jpg
#   inflating: /content/data/face_images/image00278.jpg
#   inflating: /content/data/face_images/image00696.jpg
#   inflating: /content/data/face_images/image00408.jpg
#   inflating: /content/data/face_images/image00515.jpg
#   inflating: /content/data/face_images/image00429.jpg
#   inflating: /content/data/face_images/image00274.jpg
#   inflating: /content/data/face_images/image00379.jpg
#   inflating: /content/data/face_images/image00456.jpg
#   inflating: /content/data/face_images/image00059.jpg
#   inflating: /content/data/face_images/image00270.jpg
#   inflating: /content/data/face_images/image00685.jpg
#   inflating: /content/data/face_images/image00385.jpg
#   inflating: /content/data/face_images/image00115.jpg
#   inflating: /content/data/face_images/image00410.jpg
#   inflating: /content/data/face_images/image00731.jpg
#   inflating: /content/data/face_images/image00221.jpg
#   inflating: /content/data/face_images/image00421.jpg
#   inflating: /content/data/face_images/image00733.jpg
#   inflating: /content/data/face_images/image00339.jpg
#   inflating: /content/data/face_images/image00372.jpg
#   inflating: /content/data/face_images/image00194.jpg
#   inflating: /content/data/face_images/image00319.jpg
#   inflating: /content/data/face_images/image00133.jpg
#   inflating: /content/data/face_images/image00030.jpg
#   inflating: /content/data/face_images/image00439.jpg
#   inflating: /content/data/face_images/image00646.jpg
#   inflating: /content/data/face_images/image00647.jpg
#   inflating: /content/data/face_images/image00362.jpg
#   inflating: /content/data/face_images/image00228.jpg
#   inflating: /content/data/face_images/image00031.jpg
#   inflating: /content/data/face_images/image00517.jpg
#   inflating: /content/data/face_images/image00110.jpg
#   inflating: /content/data/face_images/image00738.jpg
#   inflating: /content/data/face_images/image00181.jpg
#   inflating: /content/data/face_images/image00165.jpg
#   inflating: /content/data/face_images/image00035.jpg
#   inflating: /content/data/face_images/image00337.jpg
#   inflating: /content/data/face_images/image00353.jpg
#   inflating: /content/data/face_images/image00244.jpg
#   inflating: /content/data/face_images/image00721.jpg
#   inflating: /content/data/face_images/image00445.jpg
#   inflating: /content/data/face_images/image00046.jpg
#   inflating: /content/data/face_images/image00614.jpg
#   inflating: /content/data/face_images/image00535.jpg
#   inflating: /content/data/face_images/image00400.jpg
#   inflating: /content/data/face_images/image00546.jpg
#   inflating: /content/data/face_images/image00257.jpg
#   inflating: /content/data/face_images/image00674.jpg
#   inflating: /content/data/face_images/image00346.jpg
#   inflating: /content/data/face_images/image00370.jpg
#   inflating: /content/data/face_images/image00572.jpg
#   inflating: /content/data/face_images/image00434.jpg
#   inflating: /content/data/face_images/image00139.jpg
#   inflating: /content/data/face_images/image00342.jpg
#   inflating: /content/data/face_images/image00443.jpg
#   inflating: /content/data/face_images/image00693.jpg
#   inflating: /content/data/face_images/image00402.jpg
#   inflating: /content/data/face_images/image00596.jpg
#   inflating: /content/data/face_images/image00172.jpg
#   inflating: /content/data/face_images/image00137.jpg
#   inflating: /content/data/face_images/image00742.jpg
#   inflating: /content/data/face_images/image00435.jpg
#   inflating: /content/data/face_images/image00583.jpg
#   inflating: /content/data/face_images/image00368.jpg
#   inflating: /content/data/face_images/image00263.jpg
#   inflating: /content/data/face_images/image00480.jpg
#   inflating: /content/data/face_images/image00543.jpg
#   inflating: /content/data/face_images/image00016.jpg
#   inflating: /content/data/face_images/image00681.jpg
#   inflating: /content/data/face_images/image00426.jpg
#   inflating: /content/data/face_images/image00189.jpg
#   inflating: /content/data/face_images/image00706.jpg
#   inflating: /content/data/face_images/image00447.jpg
#   inflating: /content/data/face_images/image00555.jpg
#   inflating: /content/data/face_images/image00211.jpg
#   inflating: /content/data/face_images/image00389.jpg
#   inflating: /content/data/face_images/image00138.jpg
#   inflating: /content/data/face_images/image00636.jpg
#   inflating: /content/data/face_images/image00529.jpg
#   inflating: /content/data/face_images/image00444.jpg
#   inflating: /content/data/face_images/image00320.jpg
#   inflating: /content/data/face_images/image00363.jpg
#   inflating: /content/data/face_images/image00613.jpg
#   inflating: /content/data/face_images/image00687.jpg
#   inflating: /content/data/face_images/image00152.jpg
#   inflating: /content/data/face_images/image00605.jpg
#   inflating: /content/data/face_images/image00294.jpg
#   inflating: /content/data/face_images/image00054.jpg
#   inflating: /content/data/face_images/image00260.jpg
#   inflating: /content/data/face_images/image00258.jpg
#   inflating: /content/data/face_images/image00128.jpg
#   inflating: /content/data/face_images/image00397.jpg
#   inflating: /content/data/face_images/image00246.jpg
#   inflating: /content/data/face_images/image00215.jpg
#   inflating: /content/data/face_images/image00123.jpg
#   inflating: /content/data/face_images/image00495.jpg
#   inflating: /content/data/face_images/image00457.jpg
#   inflating: /content/data/face_images/image00022.jpg
#   inflating: /content/data/face_images/image00602.jpg
#   inflating: /content/data/face_images/image00425.jpg
#   inflating: /content/data/face_images/image00420.jpg
#   inflating: /content/data/face_images/image00740.jpg
#   inflating: /content/data/face_images/image00193.jpg
#   inflating: /content/data/face_images/image00651.jpg
#   inflating: /content/data/face_images/image00559.jpg
#   inflating: /content/data/face_images/image00505.jpg
#   inflating: /content/data/face_images/image00060.jpg
#   inflating: /content/data/face_images/image00120.jpg
#   inflating: /content/data/face_images/image00336.jpg
#   inflating: /content/data/face_images/image00430.jpg
#   inflating: /content/data/face_images/image00561.jpg
#   inflating: /content/data/face_images/image00365.jpg
#   inflating: /content/data/face_images/image00718.jpg
#   inflating: /content/data/face_images/image00020.jpg
#   inflating: /content/data/face_images/image00469.jpg
#   inflating: /content/data/face_images/image00724.jpg
#   inflating: /content/data/face_images/image00581.jpg
#   inflating: /content/data/face_images/image00689.jpg
#   inflating: /content/data/face_images/image00442.jpg
#   inflating: /content/data/face_images/image00044.jpg
#   inflating: /content/data/face_images/image00227.jpg
#   inflating: /content/data/face_images/image00369.jpg
#   inflating: /content/data/face_images/image00404.jpg
#   inflating: /content/data/face_images/image00041.jpg
#   inflating: /content/data/face_images/image00217.jpg
#   inflating: /content/data/face_images/image00214.jpg
#   inflating: /content/data/face_images/image00136.jpg
#   inflating: /content/data/face_images/image00649.jpg
#   inflating: /content/data/face_images/image00550.jpg
#   inflating: /content/data/face_images/image00045.jpg
#   inflating: /content/data/face_images/image00668.jpg
#   inflating: /content/data/face_images/image00735.jpg
#   inflating: /content/data/face_images/image00695.jpg
#   inflating: /content/data/face_images/image00487.jpg
#   inflating: /content/data/face_images/image00567.jpg
#   inflating: /content/data/face_images/image00330.jpg
#   inflating: /content/data/face_images/image00234.jpg
#   inflating: /content/data/face_images/image00201.jpg
#   inflating: /content/data/face_images/image00308.jpg
#   inflating: /content/data/face_images/image00064.jpg
#   inflating: /content/data/face_images/image00143.jpg
#   inflating: /content/data/face_images/image00144.jpg
#   inflating: /content/data/face_images/image00712.jpg
#   inflating: /content/data/face_images/image00208.jpg
#   inflating: /content/data/face_images/image00357.jpg
#   inflating: /content/data/face_images/image00355.jpg
#   inflating: /content/data/face_images/image00418.jpg
#   inflating: /content/data/face_images/image00091.jpg
#   inflating: /content/data/face_images/image00067.jpg
#   inflating: /content/data/face_images/image00549.jpg
#   inflating: /content/data/face_images/image00580.jpg
#   inflating: /content/data/face_images/image00159.jpg
#   inflating: /content/data/face_images/image00509.jpg
#   inflating: /content/data/face_images/image00200.jpg
#   inflating: /content/data/face_images/image00326.jpg
#   inflating: /content/data/face_images/image00055.jpg
#   inflating: /content/data/face_images/image00560.jpg
#   inflating: /content/data/face_images/image00513.jpg
#   inflating: /content/data/face_images/image00411.jpg
#   inflating: /content/data/face_images/image00715.jpg
#   inflating: /content/data/face_images/image00606.jpg
#   inflating: /content/data/face_images/image00504.jpg
#   inflating: /content/data/face_images/image00163.jpg
#   inflating: /content/data/face_images/image00248.jpg
#   inflating: /content/data/face_images/image00364.jpg
#   inflating: /content/data/face_images/image00414.jpg
#   inflating: /content/data/face_images/image00452.jpg
#   inflating: /content/data/face_images/image00271.jpg
#   inflating: /content/data/face_images/image00460.jpg
#   inflating: /content/data/face_images/image00717.jpg
#   inflating: /content/data/face_images/image00446.jpg
#   inflating: /content/data/face_images/image00659.jpg
#   inflating: /content/data/face_images/image00432.jpg
#   inflating: /content/data/face_images/image00621.jpg
#   inflating: /content/data/face_images/image00577.jpg
#   inflating: /content/data/face_images/image00578.jpg
#   inflating: /content/data/face_images/image00575.jpg
#   inflating: /content/data/face_images/image00625.jpg
#   inflating: /content/data/face_images/image00053.jpg
#   inflating: /content/data/face_images/image00632.jpg
#   inflating: /content/data/face_images/image00266.jpg
#   inflating: /content/data/face_images/image00295.jpg
#   inflating: /content/data/face_images/image00354.jpg
#   inflating: /content/data/face_images/image00631.jpg
#   inflating: /content/data/face_images/image00170.jpg
#   inflating: /content/data/face_images/image00299.jpg
#   inflating: /content/data/face_images/image00082.jpg
#   inflating: /content/data/face_images/image00125.jpg
#   inflating: /content/data/face_images/image00589.jpg
#   inflating: /content/data/face_images/image00262.jpg
#   inflating: /content/data/face_images/image00183.jpg
#   inflating: /content/data/face_images/image00340.jpg
#   inflating: /content/data/face_images/image00656.jpg
#   inflating: /content/data/face_images/image00746.jpg
#   inflating: /content/data/face_images/image00242.jpg
#   inflating: /content/data/face_images/image00569.jpg
#   inflating: /content/data/face_images/image00327.jpg
#   inflating: /content/data/face_images/image00011.jpg
#   inflating: /content/data/face_images/image00497.jpg
#   inflating: /content/data/face_images/image00113.jpg
#   inflating: /content/data/face_images/image00085.jpg
#   inflating: /content/data/face_images/image00617.jpg
#   inflating: /content/data/face_images/image00169.jpg
#   inflating: /content/data/face_images/image00710.jpg
#   inflating: /content/data/face_images/image00725.jpg
#   inflating: /content/data/face_images/image00306.jpg
#   inflating: /content/data/face_images/image00405.jpg
#   inflating: /content/data/face_images/image00449.jpg
#   inflating: /content/data/face_images/image00315.jpg
#   inflating: /content/data/face_images/image00465.jpg
#   inflating: /content/data/face_images/image00641.jpg
#   inflating: /content/data/face_images/image00212.jpg
#   inflating: /content/data/face_images/image00025.jpg
#   inflating: /content/data/face_images/image00403.jpg
#   inflating: /content/data/face_images/image00516.jpg
#   inflating: /content/data/face_images/image00087.jpg
#   inflating: /content/data/face_images/image00275.jpg
#   inflating: /content/data/face_images/image00078.jpg
#   inflating: /content/data/face_images/image00492.jpg
#   inflating: /content/data/face_images/image00608.jpg
#   inflating: /content/data/face_images/image00392.jpg
#   inflating: /content/data/face_images/image00259.jpg
#   inflating: /content/data/face_images/image00553.jpg
#   inflating: /content/data/face_images/image00464.jpg
#   inflating: /content/data/face_images/image00199.jpg
#   inflating: /content/data/face_images/image00173.jpg
#   inflating: /content/data/face_images/image00383.jpg
#   inflating: /content/data/face_images/image00640.jpg
#   inflating: /content/data/face_images/image00494.jpg
#   inflating: /content/data/face_images/image00027.jpg
#   inflating: /content/data/face_images/image00239.jpg
#   inflating: /content/data/face_images/image00482.jpg
#   inflating: /content/data/face_images/image00356.jpg
#   inflating: /content/data/face_images/image00171.jpg
#   inflating: /content/data/face_images/image00012.jpg
#   inflating: /content/data/face_images/image00343.jpg
#   inflating: /content/data/face_images/image00124.jpg
#   inflating: /content/data/face_images/image00079.jpg
#   inflating: /content/data/face_images/image00247.jpg
#   inflating: /content/data/face_images/image00671.jpg
#   inflating: /content/data/face_images/image00148.jpg
#   inflating: /content/data/face_images/image00018.jpg
#   inflating: /content/data/face_images/image00548.jpg
#   inflating: /content/data/face_images/image00428.jpg
#   inflating: /content/data/face_images/image00223.jpg
#   inflating: /content/data/face_images/image00077.jpg
#   inflating: /content/data/face_images/image00126.jpg
#   inflating: /content/data/face_images/image00486.jpg
#   inflating: /content/data/face_images/image00413.jpg
#   inflating: /content/data/face_images/image00395.jpg
#   inflating: /content/data/face_images/image00073.jpg
#   inflating: /content/data/face_images/image00490.jpg
#   inflating: /content/data/face_images/image00003.jpg
#   inflating: /content/data/face_images/image00458.jpg
#   inflating: /content/data/face_images/image00017.jpg
#   inflating: /content/data/face_images/image00399.jpg
#   inflating: /content/data/face_images/image00629.jpg
#   inflating: /content/data/face_images/image00155.jpg
#   inflating: /content/data/face_images/image00679.jpg
#   inflating: /content/data/face_images/image00277.jpg
#   inflating: /content/data/face_images/image00157.jpg
#   inflating: /content/data/face_images/image00032.jpg
#   inflating: /content/data/face_images/image00474.jpg
#   inflating: /content/data/face_images/image00065.jpg
#   inflating: /content/data/face_images/image00316.jpg
#   inflating: /content/data/face_images/image00069.jpg
#   inflating: /content/data/face_images/image00406.jpg
#   inflating: /content/data/face_images/image00111.jpg
#   inflating: /content/data/face_images/image00205.jpg
#   inflating: /content/data/face_images/image00536.jpg
#   inflating: /content/data/face_images/image00683.jpg
#   inflating: /content/data/face_images/image00238.jpg
#   inflating: /content/data/face_images/image00076.jpg
#   inflating: /content/data/face_images/image00526.jpg
#   inflating: /content/data/face_images/image00341.jpg
#   inflating: /content/data/face_images/image00192.jpg
#   inflating: /content/data/face_images/image00655.jpg
#   inflating: /content/data/face_images/image00264.jpg
#   inflating: /content/data/face_images/image00150.jpg
#   inflating: /content/data/face_images/image00570.jpg
#   inflating: /content/data/face_images/image00311.jpg
#   inflating: /content/data/face_images/image00349.jpg
#   inflating: /content/data/face_images/image00301.jpg
#   inflating: /content/data/face_images/image00229.jpg
#   inflating: /content/data/face_images/image00626.jpg
#   inflating: /content/data/face_images/image00040.jpg
#   inflating: /content/data/face_images/image00297.jpg
#   inflating: /content/data/face_images/image00483.jpg
#   inflating: /content/data/face_images/image00254.jpg
#   inflating: /content/data/face_images/image00601.jpg
#   inflating: /content/data/face_images/image00127.jpg
#   inflating: /content/data/face_images/image00558.jpg
#   inflating: /content/data/face_images/image00711.jpg
#   inflating: /content/data/face_images/image00116.jpg
#   inflating: /content/data/face_images/image00512.jpg
#   inflating: /content/data/face_images/image00146.jpg
#   inflating: /content/data/face_images/image00314.jpg
#   inflating: /content/data/face_images/image00637.jpg
#   inflating: /content/data/face_images/image00500.jpg
#   inflating: /content/data/face_images/image00261.jpg
#   inflating: /content/data/face_images/image00222.jpg
#   inflating: /content/data/face_images/image00376.jpg
#   inflating: /content/data/face_images/image00280.jpg
#   inflating: /content/data/face_images/image00237.jpg
#   inflating: /content/data/face_images/image00213.jpg
#   inflating: /content/data/face_images/image00468.jpg
#   inflating: /content/data/face_images/image00063.jpg
#   inflating: /content/data/face_images/image00034.jpg
#   inflating: /content/data/face_images/image00398.jpg
#   inflating: /content/data/face_images/image00514.jpg
#   inflating: /content/data/face_images/image00467.jpg
#   inflating: /content/data/face_images/image00600.jpg
#   inflating: /content/data/face_images/image00374.jpg
#   inflating: /content/data/face_images/image00130.jpg
#   inflating: /content/data/face_images/image00501.jpg
#   inflating: /content/data/face_images/image00662.jpg
#   inflating: /content/data/face_images/image00245.jpg
#   inflating: /content/data/face_images/image00216.jpg
#   inflating: /content/data/face_images/image00103.jpg
#   inflating: /content/data/face_images/image00285.jpg
#   inflating: /content/data/face_images/image00195.jpg
#   inflating: /content/data/face_images/image00642.jpg
#   inflating: /content/data/face_images/image00713.jpg
#   inflating: /content/data/face_images/image00381.jpg
#   inflating: /content/data/face_images/image00240.jpg
#   inflating: /content/data/face_images/image00590.jpg
#   inflating: /content/data/face_images/image00654.jpg
#   inflating: /content/data/face_images/image00574.jpg
#   inflating: /content/data/face_images/image00436.jpg
#   inflating: /content/data/face_images/image00058.jpg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tensorflow as tf
import cv2
import os
import glob

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_data = []
for img in os.listdir("/content/data/face_images"):
  img_file = cv2.imread("/content/data/face_images/" + img)
  if(type(img_file) != type(None)):
    img_data.append(img_file)

# %%
cv2.imwrite("/content/data/1.jpg", img_data[0])
# Out:
# True

# %%
len(img_data)
# Out:
# 750

# %%
count = 0
for i in img_data:
  if(type(i) == type(None)):
    print(count)
  count += 1

# %%
del img_data[573]

# %%
# https://towardsdatascience.com/complete-image-augmentation-in-opencv-31a6b02694f5
import random

def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img

# HORIZONTAL SHIFT - RANDOM RATIO 0 - 1
def horizontal_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = w*ratio
    if ratio > 0:
        img = img[:, :int(w-to_shift), :]
    if ratio < 0:
        img = img[:, int(-1*to_shift):, :]
    img = fill(img, h, w)
    return img

# VERTICAL SHIFT - RANDOM RATIO 0 - 1
def vertical_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = h*ratio
    if ratio > 0:
        img = img[:int(h-to_shift), :, :]
    if ratio < 0:
        img = img[int(-1*to_shift):, :, :]
    img = fill(img, h, w)
    return img

# BRIGHTNESS - RANDOM LOW, HIGH 
def brightness(img, low, high):
    value = random.uniform(low, high)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv = np.array(hsv, dtype = np.float64)
    hsv[:,:,1] = hsv[:,:,1]*value
    hsv[:,:,1][hsv[:,:,1]>255]  = 255
    hsv[:,:,2] = hsv[:,:,2]*value 
    hsv[:,:,2][hsv[:,:,2]>255]  = 255
    hsv = np.array(hsv, dtype = np.uint8)
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return img

# ZOOM - RANDOM VALUE 0 - 1
def zoom(img, value):
    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, h, w)
    return img

# HORIZONTAL FLIP - RANDOM BOOLEAN
def horizontal_flip(img, flag):
    if flag:
        return cv2.flip(img, 1)
    else:
        return img

# VERTICAL FLIP - RANDOM BOOLEAN
def vertical_flip(img, flag):
    if flag:
        return cv2.flip(img, 0)
    else:
        return img

# ROTATION - RANDOM ANGLE
def rotation(img, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = img.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    img = cv2.warpAffine(img, M, (w, h))
    return img

# %%
img_temp = cv2.imread("/content/data/face_images/image00072.jpg")
img_temp = cv2.cvtColor(img_temp, cv2.COLOR_BGR2RGB)
img_aug_1 = horizontal_shift(img_temp, 0.6)
img_aug_2 = vertical_shift(img_temp, 0.7)
img_aug_3 = brightness(img_temp, 0.3, 5)
img_aug_4 = zoom(img_temp, 0.5)
img_aug_5 = horizontal_flip(img_temp, True)
img_aug_6 = vertical_flip(img_temp,True)
img_aug_7 = rotation(img_temp, 45)
img_aug_8 = brightness(img_temp, 0, 10)

fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7, ax8, ax9)) = plt.subplots(nrows=3,ncols=3,figsize=(15,10))

ax1.imshow(img_aug_1)
ax1.set_title("Horizontal Shift")
ax2.imshow(img_aug_2)
ax2.set_title("Vertical Shift")
ax3.imshow(img_aug_3)
ax3.set_title("Brightness")
ax4.imshow(img_aug_4)
ax4.set_title("Zoom")
ax5.imshow(img_aug_5)
ax5.set_title("Horizontal Flip")
ax6.imshow(img_aug_6)
ax6.set_title("Vertical Flip")
ax7.imshow(img_aug_7)
ax7.set_title("Rotation")
ax8.imshow(img_aug_8)
ax8.set_title("Brightness too much")
ax9.imshow(img_temp)
ax9.set_title("Original Img")

plt.show()

# %%
def scale(img, value):
  return np.array((value * img), dtype=np.uint8)

plt.imshow(scale(img_temp, 0.6))
plt.show()

# %%
img_augmented_data = []
for i in img_data:
  img_augmented_data.append(i)
  for j in range(3):
    img_augmented_data.append(horizontal_shift(i, random.uniform(0, 1)))
    img_augmented_data.append(vertical_shift(i, random.uniform(0, 1)))
    img_augmented_data.append(zoom(i, random.uniform(0, 1)))
    img_augmented_data.append(scale(i, random.uniform(0.6, 1)))
  # break

# %%
img = cv2.cvtColor(img_augmented_data[0], cv2.COLOR_BGR2RGB)
imageLAB = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
L, a, b = cv2.split(imageLAB)

# %%
a_scaled = np.uint8(255.*(a - a.min())/(a.max() - a.min()))
b_scaled = np.uint8(255.*(b - a.min())/(b.max() - b.min()))

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,8))

ax1.imshow(img)
ax1.set_title("Original Image")
ax2.imshow(L)
ax2.set_title("L")
ax3.imshow(a)
ax3.set_title("A")
ax4.imshow(b)
ax4.set_title("B")
plt.show()

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,8))

ax1.imshow(img)
ax1.set_title("Original Image")
ax2.imshow(L)
ax2.set_title("L")
ax3.imshow(a_scaled)
ax3.set_title("A")
ax4.imshow(b_scaled)
ax4.set_title("B")
plt.show()

# %%
L_data = []
a_data = []
b_data = []
count = 0
for img in img_augmented_data:
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  L_data.append(L)
  a_data.append(a)
  b_data.append(b)
  # cv2.imwrite("/content/augmented_dataset/aug/imageaug" + str(count) + ".jpg", img)
  # cv2.imwrite("/content/augmented_dataset/augLab/imageaugLab" + str(count) + ".jpg", imageLAB)
  # cv2.imwrite("/content/augmented_dataset/aug_L/imageaugL" + str(count) + ".jpg", L)
  # cv2.imwrite("/content/augmented_dataset/aug_a/imageauga" + str(count) + ".jpg", a)
  # cv2.imwrite("/content/augmented_dataset/aug_b/imageaugb" + str(count) + ".jpg", b)
  count += 1

# %%
# !zip -r "/content/augmented_data.zip" "/content/augmented_dataset"

# %%
# from google.colab import files
# files.download("/content/augmented_data.zip")

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread("/content/data/face_images/image00004.jpg")
imageLAB = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
cv2_imshow(image)
cv2_imshow(imageLAB)
L,a,b=cv2.split(imageLAB)
cv2_imshow(L)
cv2_imshow(a)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F0132D8D190>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F0132D8D810>
# <PIL.Image.Image image mode=L size=128x128 at 0x7F01325E9350>
# <PIL.Image.Image image mode=L size=128x128 at 0x7F01325E9350>
# <PIL.Image.Image image mode=L size=128x128 at 0x7F01325E9350>

# %%
X_data = np.array(L_data, dtype = np.uint8)
X_data = X_data / 255
X_data.shape , np.amax(X_data)
# Out:
# ((9750, 128, 128), 0.996078431372549)

# %%
y_data = []
a_mean = []
b_mean = []
for i in range(len(a_data)):
  y_data.append([np.average(a_data[i]), np.average(b_data[i])])
  a_mean.append(np.average(a_data[i]))
  b_mean.append(np.average(b_data[i]))
y_data = np.array(y_data, dtype = np.float32)
y_data = y_data / 255
y_data.shape, np.amax(y_data)
# Out:
# ((9750, 2), 0.60852265)

# %%
plt.hist(a_mean, bins=100)
plt.show()

# %%
plt.hist(b_mean, bins=100)
plt.show()

# %%
import random
train_indices = []
for i in range(7800):
  x = random.randint(0, 9749)
  while(x in train_indices):
    x = random.randint(0, 9749)
  train_indices.append(x)
print(len(train_indices))
train_indices = list(set(train_indices))
print(len(train_indices))
# Out:
# 7800
# 7800

# %%
X_train = []
X_test = []
y_train = []
y_test = []

for i in range(9750):
  if(i in train_indices):
    X_train.append(X_data[i])
    y_train.append(y_data[i])
  else:
    X_test.append(X_data[i])
    y_test.append(y_data[i])

X_train = np.array(X_train, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)
y_test= np.array(y_test, dtype=np.float32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7800, 128, 128), (1950, 128, 128), (7800, 2), (1950, 2))

# %%
X_train = X_train.reshape(7800, 1 , 128, 128)
X_test = X_test.reshape(1950, 1, 128, 128)
X_train.shape
# Out:
# (7800, 1, 128, 128)

# %%
y_train = y_train.reshape(7800, 1, 1, 2)
y_test = y_test.reshape(1950, 1, 1, 2)

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Conv2D
model = Sequential()
model.add(Input(shape = (X_train[0].shape)))
model.add(Conv2D(64, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(32, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(16, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(8, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(4, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(2, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Conv2D(2, 2, activation = "relu",strides = 2,padding = 'same', input_shape=X_train.shape[1:]))
model.add(Dense(2,activation='relu'))
# model.add(Dense(1,activation='relu'))
model.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_130 (Conv2D)         (None, 1, 64, 64)         32832
#
#  conv2d_131 (Conv2D)         (None, 1, 32, 32)         8224
#
#  conv2d_132 (Conv2D)         (None, 1, 16, 16)         2064
#
#  conv2d_133 (Conv2D)         (None, 1, 8, 8)           520
#
#  conv2d_134 (Conv2D)         (None, 1, 4, 4)           132
#
#  conv2d_135 (Conv2D)         (None, 1, 2, 2)           34
#
#  conv2d_136 (Conv2D)         (None, 1, 1, 2)           18
#
#  dense_17 (Dense)            (None, 1, 1, 2)           6
#
# =================================================================
# Total params: 43,830
# Trainable params: 43,830
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = tf.keras.losses.MeanSquaredError(name='mean_squared_error')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss=loss)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lrr = ReduceLROnPlateau(monitor='val_loss', 
                        patience=5, 
                        verbose=1, 
                        factor=0.4, 
                        min_lr=0.0001)

# %%
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=50, 
                    batch_size=512,
                    steps_per_epoch=X_train.shape[0]//512,
                    validation_steps=X_test.shape[0]//512,
                    callbacks=[lrr],
                    shuffle=True)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 46ms/step - loss: 2.8208e-04 - val_loss: 3.1055e-04 - lr: 0.0010
# Epoch 2/50
# 15/15 [==============================] - 1s 36ms/step - loss: 2.5423e-04 - val_loss: 2.5728e-04 - lr: 0.0010
# Epoch 3/50
# 15/15 [==============================] - 1s 34ms/step - loss: 2.4194e-04 - val_loss: 2.5042e-04 - lr: 0.0010
# Epoch 4/50
# 15/15 [==============================] - 0s 33ms/step - loss: 2.2882e-04 - val_loss: 2.2867e-04 - lr: 0.0010
# Epoch 5/50
# 15/15 [==============================] - 0s 33ms/step - loss: 2.2517e-04 - val_loss: 2.6320e-04 - lr: 0.0010
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 2.2244e-04
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 15/15 [==============================] - 0s 33ms/step - loss: 2.2209e-04 - val_loss: 2.1890e-04 - lr: 0.0010
# Epoch 7/50
# 15/15 [==============================] - 1s 34ms/step - loss: 2.0795e-04 - val_loss: 2.1378e-04 - lr: 4.0000e-04
# Epoch 8/50
# 15/15 [==============================] - 0s 33ms/step - loss: 2.0176e-04 - val_loss: 2.1148e-04 - lr: 4.0000e-04
# Epoch 9/50
# 15/15 [==============================] - 0s 33ms/step - loss: 2.0269e-04 - val_loss: 2.0947e-04 - lr: 4.0000e-04
# Epoch 10/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9891e-04 - val_loss: 2.0838e-04 - lr: 4.0000e-04
# Epoch 11/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9773e-04 - val_loss: 2.0699e-04 - lr: 4.0000e-04
# Epoch 12/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9548e-04 - val_loss: 2.0753e-04 - lr: 4.0000e-04
# Epoch 13/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9706e-04 - val_loss: 2.0762e-04 - lr: 4.0000e-04
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9761e-04
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9650e-04 - val_loss: 2.1237e-04 - lr: 4.0000e-04
# Epoch 15/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9479e-04 - val_loss: 2.0334e-04 - lr: 1.6000e-04
# Epoch 16/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9359e-04 - val_loss: 2.0347e-04 - lr: 1.6000e-04
# Epoch 17/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9269e-04 - val_loss: 2.0441e-04 - lr: 1.6000e-04
# Epoch 18/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9452e-04 - val_loss: 2.0221e-04 - lr: 1.6000e-04
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9099e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001.
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9046e-04 - val_loss: 2.0246e-04 - lr: 1.6000e-04
# Epoch 20/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9208e-04 - val_loss: 2.0164e-04 - lr: 1.0000e-04
# Epoch 21/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9322e-04 - val_loss: 2.0151e-04 - lr: 1.0000e-04
# Epoch 22/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8868e-04 - val_loss: 2.0233e-04 - lr: 1.0000e-04
# Epoch 23/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9067e-04 - val_loss: 2.0101e-04 - lr: 1.0000e-04
# Epoch 24/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9132e-04 - val_loss: 2.0152e-04 - lr: 1.0000e-04
# Epoch 25/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.9272e-04 - val_loss: 2.0077e-04 - lr: 1.0000e-04
# Epoch 26/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8896e-04 - val_loss: 2.0171e-04 - lr: 1.0000e-04
# Epoch 27/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9091e-04 - val_loss: 2.0073e-04 - lr: 1.0000e-04
# Epoch 28/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.9060e-04 - val_loss: 2.0051e-04 - lr: 1.0000e-04
# Epoch 29/50
# 15/15 [==============================] - 1s 35ms/step - loss: 1.8965e-04 - val_loss: 1.9992e-04 - lr: 1.0000e-04
# Epoch 30/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8921e-04 - val_loss: 2.0035e-04 - lr: 1.0000e-04
# Epoch 31/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8870e-04 - val_loss: 1.9967e-04 - lr: 1.0000e-04
# Epoch 32/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8904e-04 - val_loss: 2.0019e-04 - lr: 1.0000e-04
# Epoch 33/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8898e-04 - val_loss: 1.9929e-04 - lr: 1.0000e-04
# Epoch 34/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8896e-04 - val_loss: 1.9890e-04 - lr: 1.0000e-04
# Epoch 35/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8829e-04 - val_loss: 1.9908e-04 - lr: 1.0000e-04
# Epoch 36/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8846e-04 - val_loss: 1.9859e-04 - lr: 1.0000e-04
# Epoch 37/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8649e-04 - val_loss: 1.9891e-04 - lr: 1.0000e-04
# Epoch 38/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8930e-04 - val_loss: 1.9853e-04 - lr: 1.0000e-04
# Epoch 39/50
# 15/15 [==============================] - 0s 31ms/step - loss: 1.8722e-04 - val_loss: 1.9830e-04 - lr: 1.0000e-04
# Epoch 40/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8795e-04 - val_loss: 1.9807e-04 - lr: 1.0000e-04
# Epoch 41/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8810e-04 - val_loss: 1.9839e-04 - lr: 1.0000e-04
# Epoch 42/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8827e-04 - val_loss: 1.9981e-04 - lr: 1.0000e-04
# Epoch 43/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8700e-04 - val_loss: 1.9840e-04 - lr: 1.0000e-04
# Epoch 44/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8735e-04 - val_loss: 1.9768e-04 - lr: 1.0000e-04
# Epoch 45/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8798e-04 - val_loss: 1.9735e-04 - lr: 1.0000e-04
# Epoch 46/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8774e-04 - val_loss: 1.9725e-04 - lr: 1.0000e-04
# Epoch 47/50
# 15/15 [==============================] - 0s 32ms/step - loss: 1.8697e-04 - val_loss: 1.9942e-04 - lr: 1.0000e-04
# Epoch 48/50
# 15/15 [==============================] - 0s 33ms/step - loss: 1.8828e-04 - val_loss: 1.9821e-04 - lr: 1.0000e-04
# Epoch 49/50
# 15/15 [==============================] - 1s 35ms/step - loss: 1.8644e-04 - val_loss: 1.9923e-04 - lr: 1.0000e-04
# Epoch 50/50
# 15/15 [==============================] - 0s 34ms/step - loss: 1.8563e-04 - val_loss: 1.9708e-04 - lr: 1.0000e-04

# %%
for i in range(10):
  r = random.randint(0, 1949)
  pred = model.predict(X_test[r].reshape(1,1,128,128))
  a = pred[0][0][0][0] * 255
  b = pred[0][0][0][1] * 255
  a_real = y_test[0][0][0][0] * 255
  b_real = y_test[0][0][0][1] * 255
  # print(model.predict(X_test[r].reshape(1,1,128,128)) , y_test[r])
  print(a_real, " --- ", a)
  print(b_real, " --- ", b)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 139.80597406625748  ---  142.84938275814056
# 141.24450087547302  ---  144.28766638040543
# 1/1 [==============================] - 0s 24ms/step
# 139.80597406625748  ---  139.56900358200073
# 141.24450087547302  ---  138.46250295639038
# 1/1 [==============================] - 0s 24ms/step
# 139.80597406625748  ---  139.84593272209167
# 141.24450087547302  ---  138.95424216985703
# 1/1 [==============================] - 0s 27ms/step
# 139.80597406625748  ---  139.23185527324677
# 141.24450087547302  ---  137.8638070821762
# 1/1 [==============================] - 0s 26ms/step
# 139.80597406625748  ---  138.95732760429382
# 141.24450087547302  ---  137.37632364034653
# 1/1 [==============================] - 0s 27ms/step
# 139.80597406625748  ---  141.4107495546341
# 141.24450087547302  ---  141.7330026626587
# 1/1 [==============================] - 0s 28ms/step
# 139.80597406625748  ---  141.0041105747223
# 141.24450087547302  ---  141.010904610157
# 1/1 [==============================] - 0s 57ms/step
# 139.80597406625748  ---  140.45861184597015
# 141.24450087547302  ---  140.04221498966217
# 1/1 [==============================] - 0s 30ms/step
# 139.80597406625748  ---  139.55374360084534
# 141.24450087547302  ---  138.43540281057358
# 1/1 [==============================] - 0s 30ms/step
# 139.80597406625748  ---  139.01470452547073
# 141.24450087547302  ---  137.47818857431412

# %%
# PLOTTING THE ACCURACY AND VALIDATION ACCURACY VS EPOCHS
from matplotlib import pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Mean Squared Error')
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("/content/drive/MyDrive/DLCG_PART_2/mean_chrominance_model.h5")

# %%
model.evaluate(X_test, y_test)
# Out:
# 61/61 [==============================] - 1s 6ms/step - loss: 1.9893e-04
# 0.0001989256707020104
