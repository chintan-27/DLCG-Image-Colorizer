# %%
# !unzip "/content/face_images.zip" -d "/content/data"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tensorflow as tf
import cv2
import os
import glob

# %%
img_data = []
for img in os.listdir("/content/data/face_images"):
  img_file = cv2.imread("/content/data/face_images/" + img)
  if(type(img_file) != type(None)):
    img_data.append(img_file)

# %%
len(img_data)
# Out:
# 750

# %%
# https://towardsdatascience.com/complete-image-augmentation-in-opencv-31a6b02694f5
import random

def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img

# HORIZONTAL SHIFT - RANDOM RATIO 0 - 1
def horizontal_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = w*ratio
    if ratio > 0:
        img = img[:, :int(w-to_shift), :]
    if ratio < 0:
        img = img[:, int(-1*to_shift):, :]
    img = fill(img, h, w)
    return img

# VERTICAL SHIFT - RANDOM RATIO 0 - 1
def vertical_shift(img, ratio=0.0):
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = h*ratio
    if ratio > 0:
        img = img[:int(h-to_shift), :, :]
    if ratio < 0:
        img = img[int(-1*to_shift):, :, :]
    img = fill(img, h, w)
    return img

# BRIGHTNESS - RANDOM LOW, HIGH 
def brightness(img, low, high):
    value = random.uniform(low, high)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv = np.array(hsv, dtype = np.float64)
    hsv[:,:,1] = hsv[:,:,1]*value
    hsv[:,:,1][hsv[:,:,1]>255]  = 255
    hsv[:,:,2] = hsv[:,:,2]*value 
    hsv[:,:,2][hsv[:,:,2]>255]  = 255
    hsv = np.array(hsv, dtype = np.uint8)
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return img

# ZOOM - RANDOM VALUE 0 - 1
def zoom(img, value):
    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, h, w)
    return img

# HORIZONTAL FLIP - RANDOM BOOLEAN
def horizontal_flip(img, flag):
    if flag:
        return cv2.flip(img, 1)
    else:
        return img

# VERTICAL FLIP - RANDOM BOOLEAN
def vertical_flip(img, flag):
    if flag:
        return cv2.flip(img, 0)
    else:
        return img

# ROTATION - RANDOM ANGLE
def rotation(img, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = img.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    img = cv2.warpAffine(img, M, (w, h))
    return img
  
# SCALE - RANDOM VALUE 0.6 - 1
def scale(img, value):
  return np.array((value * img), dtype=np.uint8)

# %%
import random
train_indices = []
for i in range(675):
  x = random.randint(0, 749)
  while(x in train_indices):
    x = random.randint(0, 749)
  train_indices.append(x)
print(len(train_indices))
train_indices = list(set(train_indices))
print(len(train_indices))
# Out:
# 675
# 675

# %%
train_data = []
test_data = []

for i in range(750):
  if(i in train_indices):
    train_data.append(img_data[i])
  else:
    test_data.append(img_data[i])

train_data = np.array(train_data, dtype=np.float32)
test_data = np.array(test_data, dtype=np.float32)

train_data.shape, test_data.shape
# Out:
# ((675, 128, 128, 3), (75, 128, 128, 3))

# %%
augmented_train_data = []
for i in train_data:
  augmented_train_data.append(i)
  for j in range(3):
    augmented_train_data.append(horizontal_shift(i, random.uniform(0, 1)))
    augmented_train_data.append(vertical_shift(i, random.uniform(0, 1)))
    augmented_train_data.append(zoom(i, random.uniform(0, 1)))
    augmented_train_data.append(scale(i, random.uniform(0.6, 1)))

# %%
X_train = []
y_train = []
for img in augmented_train_data:
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  X_train.append([L])
  y_train.append([a,b])

# %%
X_test = []
y_test = []
for img in test_data:
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  X_test.append([L])
  y_test.append([a,b])

# %%
X_train = np.array(X_train, dtype = np.float32)
X_test = np.array(X_test, dtype = np.float32)
y_train = np.array(y_train, dtype = np.float32)
y_test = np.array(y_test, dtype = np.float32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8775, 1, 128, 128),
#  (75, 1, 128, 128),
#  (8775, 2, 128, 128),
#  (75, 2, 128, 128))

# %%
X_train = X_train / 255
X_test = X_test / 255
y_train = y_train / 255
y_test = y_test / 255

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Conv2D, Conv2DTranspose, BatchNormalization
model = Sequential()
model.add(Input(shape = (X_train[0].shape)))
model.add(Conv2D(128, 2, activation = "relu",strides = 1,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(256, 1, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(128, 2, activation = "relu",strides =  (2, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(64, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(32, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(16, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(8, 2, activation = "relu",strides = 2,padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(8, 2, activation = "relu",strides = (2, 1),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(16, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(32, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(64, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(128, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(256, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(128, 2, activation = "relu",strides = (1, 2),padding = 'same'))
model.add(BatchNormalization())

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1, 128, 128)       65664
#
#  batch_normalization (BatchN  (None, 1, 128, 128)      512
#  ormalization)
#
#  conv2d_transpose (Conv2DTra  (None, 1, 256, 256)      33024
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 1, 256, 256)      1024
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 1, 128, 128)       131200
#
#  batch_normalization_2 (Batc  (None, 1, 128, 128)      512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 1, 64, 64)         32832
#
#  batch_normalization_3 (Batc  (None, 1, 64, 64)        256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 1, 32, 32)         8224
#
#  batch_normalization_4 (Batc  (None, 1, 32, 32)        128
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 1, 16, 16)         2064
#
#  batch_normalization_5 (Batc  (None, 1, 16, 16)        64
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 1, 8, 8)           520
#
#  batch_normalization_6 (Batc  (None, 1, 8, 8)          32
#  hNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 2, 8, 8)          264
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 2, 8, 8)          32
#  hNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 2, 16, 16)        528
#  ranspose)
#
#  batch_normalization_8 (Batc  (None, 2, 16, 16)        64
#  hNormalization)
#
#  conv2d_transpose_3 (Conv2DT  (None, 2, 32, 32)        2080
#  ranspose)
#
#  batch_normalization_9 (Batc  (None, 2, 32, 32)        128
#  hNormalization)
#
#  conv2d_transpose_4 (Conv2DT  (None, 2, 64, 64)        8256
#  ranspose)
#
#  batch_normalization_10 (Bat  (None, 2, 64, 64)        256
#  chNormalization)
#
#  conv2d_transpose_5 (Conv2DT  (None, 2, 128, 128)      32896
#  ranspose)
#
#  batch_normalization_11 (Bat  (None, 2, 128, 128)      512
#  chNormalization)
#
#  conv2d_transpose_6 (Conv2DT  (None, 2, 256, 256)      131328
#  ranspose)
#
#  batch_normalization_12 (Bat  (None, 2, 256, 256)      1024
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 2, 128, 128)       131200
#
#  batch_normalization_13 (Bat  (None, 2, 128, 128)      512
#  chNormalization)
#
# =================================================================
# Total params: 585,136
# Trainable params: 582,608
# Non-trainable params: 2,528
# _________________________________________________________________

# %%
loss = tf.keras.losses.MeanSquaredError(name='mean_squared_error')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss=loss)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lrr = ReduceLROnPlateau(monitor='val_loss', 
                        patience=7, 
                        verbose=1, 
                        factor=0.4, 
                        min_lr=0.0001)

# %%
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=30, 
                    batch_size=25,
                    steps_per_epoch=X_train.shape[0]//25,
                    validation_steps=X_test.shape[0]//25,
                    callbacks=[lrr],
                    shuffle=True)
# Out:
# Epoch 1/30
# 351/351 [==============================] - 14s 10ms/step - loss: 0.4065 - val_loss: 0.0428 - lr: 0.0010
# Epoch 2/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.1311 - val_loss: 1.0067 - lr: 0.0010
# Epoch 3/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0334 - val_loss: 0.5079 - lr: 0.0010
# Epoch 4/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0080 - val_loss: 0.3604 - lr: 0.0010
# Epoch 5/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0039 - val_loss: 0.2786 - lr: 0.0010
# Epoch 6/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 0.2762 - lr: 0.0010
# Epoch 7/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0035 - val_loss: 3.3291e-04 - lr: 0.0010
# Epoch 8/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 0.2904 - lr: 0.0010
# Epoch 9/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 6.9642e-04 - lr: 0.0010
# Epoch 10/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0028 - val_loss: 0.0018 - lr: 0.0010
# Epoch 11/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0034 - val_loss: 3.8471e-04 - lr: 0.0010
# Epoch 12/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0031 - val_loss: 0.2937 - lr: 0.0010
# Epoch 13/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0034 - val_loss: 0.2688 - lr: 0.0010
# Epoch 14/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 1.1779e-04 - lr: 0.0010
# Epoch 15/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0038 - val_loss: 0.2593 - lr: 0.0010
# Epoch 16/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 0.1983 - lr: 0.0010
# Epoch 17/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 0.2907 - lr: 0.0010
# Epoch 18/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0035 - val_loss: 9.1209e-04 - lr: 0.0010
# Epoch 19/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0031 - val_loss: 9.8341e-05 - lr: 0.0010
# Epoch 20/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0036 - val_loss: 0.2548 - lr: 0.0010
# Epoch 21/30
# 349/351 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0034 - val_loss: 9.5415e-05 - lr: 0.0010
# Epoch 22/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 9.1617e-05 - lr: 4.0000e-04
# Epoch 23/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 1.0092e-04 - lr: 4.0000e-04
# Epoch 24/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0034 - val_loss: 8.6660e-05 - lr: 4.0000e-04
# Epoch 25/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0029 - val_loss: 8.9389e-05 - lr: 4.0000e-04
# Epoch 26/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0032 - val_loss: 1.0292e-04 - lr: 4.0000e-04
# Epoch 27/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0033 - val_loss: 9.7581e-05 - lr: 4.0000e-04
# Epoch 28/30
# 351/351 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0030 - val_loss: 9.2063e-05 - lr: 4.0000e-04
# Epoch 29/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0034 - val_loss: 1.0879e-04 - lr: 1.6000e-04
# Epoch 30/30
# 351/351 [==============================] - 3s 9ms/step - loss: 0.0031 - val_loss: 8.3209e-05 - lr: 1.6000e-04

# %%
# PLOTTING THE ACCURACY AND VALIDATION ACCURACY VS EPOCHS
from matplotlib import pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Mean Squared Error')
plt.ylabel('MSE')
plt.xlabel('epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("/content//ColorizerModelFinal.h5")

# %%
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 1s 46ms/step - loss: 8.3209e-05
# 8.320942288264632e-05

# %%
def predict(imgpath, flag):
  img = cv2.imread(imgpath)
  img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
  print(img.shape)
  imageLAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  L, a, b = cv2.split(imageLAB)
  L = L.reshape(1 , 1, 128, 128)
  L = L/255
  pred = model.predict(L)
  a = pred[0][0]
  b = pred[0][1]
  L = L.reshape(128,128)
  L = np.array(L * 255, dtype = np.uint8)
  a = np.array(a * 255, dtype = np.uint8)
  b = np.array(b * 255, dtype = np.uint8)

  imgLAB = cv2.merge([L, a, b])
  image = cv2.cvtColor(imgLAB, cv2.COLOR_LAB2RGB)
  fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(5,8))

  ax1.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  ax1.set_title("Original Image")
  ax2.imshow(image)
  ax2.set_title("Colorized")
  ax3.imshow(a)
  ax3.set_title("a")
  ax4.imshow(b)
  ax4.set_title("b")
  # cv2.imwrite("/content/img.jpg", cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
  # if(not flag):
  #   image = predict("/content/img.jpg", True)
  return image

# %%
image = predict("/content/2.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 416ms/step

# %%
image = predict("/content/3.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 18ms/step

# %%
image = predict("/content/4.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 19ms/step

# %%
image = predict("/content/5.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 19ms/step

# %%
image = predict("/content/6.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 20ms/step

# %%
image = predict("/content/7.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 19ms/step

# %%
image = predict("/content/8.png", False)
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 23ms/step
